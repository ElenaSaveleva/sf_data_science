# %% [markdown]
# <a href="https://colab.research.google.com/github/ElenaSaveleva/sf_data_science/blob/main/PYTHON_11.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

trip_data = pd.read_csv('/content/citibike-tripdata.csv', sep=',')
display(trip_data)
# Out:
#                        starttime                  stoptime  start station id  \
# 0       2018-09-01 00:00:05.2690  2018-09-01 00:27:20.6340             252.0
# 1       2018-09-01 00:00:11.2810  2018-09-01 00:02:23.4810             314.0
# 2       2018-09-01 00:00:20.6490  2018-09-01 00:55:58.5470            3142.0
# 3       2018-09-01 00:00:21.7460  2018-09-01 00:07:38.5830             308.0
# 4       2018-09-01 00:00:27.3150  2018-09-01 02:21:25.3080             345.0
# ...                          ...                       ...               ...
# 299995  2018-09-05 19:08:27.8460  2018-09-05 19:15:51.4940             494.0
# 299996  2018-09-05 19:08:28.3700  2018-09-05 19:20:01.5080            3016.0
# 299997  2018-09-05 19:08:27.5090  2018-09-05 19:13:40.5060            3686.0
# 299998  2018-09-05 19:08:29.2300  2018-09-05 20:04:29.3220             254.0
# 299999  2018-09-05 19:08:29.7110  2018-09-05 19:12:14.7620            3496.0
#
# ...

# %%
trip_data = pd.read_csv('/content/citibike-tripdata.csv', sep=',')
trip_data['end station name'].value_counts()
# Out:
# West St & Chambers St          1963
# 12 Ave & W 40 St               1909
# Pershing Square North          1850
# Central Park S & 6 Ave         1828
# E 17 St & Broadway             1804
#                                ...
# Exchange Place                    3
# Union St                          1
# Warren St                         1
# Montrose Ave & Bushwick Ave       1
# Liberty Light Rail                1
# Name: end station name, Length: 765, dtype: int64

# %%
import pandas as pd

trip_data = pd.read_csv('/content/citibike-tripdata.csv', sep=',')
trip_data_df = trip_data.copy()
trip_data_df = trip_data_df.drop('start station id', axis = 1)
trip_data_df = trip_data_df.drop('end station id', axis = 1)
trip_data_df['age'] = 2018 - trip_data_df['birth year']
trip_data_df.drop(['birth year'], axis=1, inplace=True)
print(trip_data_df[trip_data_df['age'] > 60].shape[0])
trip_data_df['starttime'] = pd.to_datetime(trip_data_df['starttime'])
trip_data_df['stoptime'] = pd.to_datetime(trip_data_df['stoptime'])
trip_data_df['trip duration'] = (trip_data_df['stoptime'] - trip_data_df['starttime'])
trip_data_df.loc[3, 'trip duration']
# Out:
# 11837
# Timedelta('0 days 00:07:16.837000')
